# %%
import pandas as pd
import datetime

# %%
from factors_exposure.beta import Beta

# %%
beta = Beta('BETA', None)

# %%
print(beta.calcBeta_ESTU(datetime.date(2019,1,3)).head())
# Out:
# Stock AMCR is short on data. 110 / 251 , Will be eliminated from ESTU
# Stock  BRK.B  not found in database.
# Stock  BF.B  not found in database.
# Stock CARR is short on data. 0 / 251 , Will be eliminated from ESTU
# Stock CDAY is short on data. 173 / 251 , Will be eliminated from ESTU
# Stock CTVA is short on data. 0 / 251 , Will be eliminated from ESTU
# Stock DOW is short on data. 0 / 251 , Will be eliminated from ESTU
# Stock FOXA is short on data. 0 / 251 , Will be eliminated from ESTU
# Stock FOX is short on data. 0 / 251 , Will be eliminated from ESTU
# Stock MRNA is short on data. 17 / 251 , Will be eliminated from ESTU
# Stock OGN is short on data. 0 / 251 , Will be eliminated from ESTU
# Stock OTIS is short on data. 0 / 251 , Will be eliminated from ESTU
#   Stock      Beta        Date
# 0   MMM  0.752373  2019-01-03
# 1   AOS  0.665941  2019-01-03
# 2   ABT  0.824050  2019-01-03
# 3  ABBV  0.682418  2019-01-03
# 4  ABMD  1.519680  2019-01-03

# %%
len(beta.weight)
# Out:
# 251

# %%
beta.rf.head()
# Out:
#            Date        rf
# 502  2018-01-03  0.002367
# 503  2018-01-04  0.002367
# 504  2018-01-05  0.002367
# 505  2018-01-08  0.002378
# 506  2018-01-09  0.002419

# %%
beta.ESTU
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ABMD',
#  'ACN',
#  'ATVI',
#  'ADM',
#  'ADBE',
#  'AAP',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'AKAM',
#  'ALK',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'ABC',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'ANTM',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'BKR',
#  'BLL',
#  'BAC',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BK',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'CHRW',
#  'CDNS',
#  'CZR',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'CNC',
# ...
